# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
"""
PS: EXECUTE plot statements one by one. Plotting everything at the same time is resulting in 
OVERLAP

"""

cars_data = pd.read_csv('Toyota.csv',na_values=['??','????'], index_col = 0)
cars_data.dropna(axis = 0, inplace = True)


#pairwise plots
#used to plot pairwise relationships in a dataset
#creates scatterplots for joint relationships and histograms for univariate distributions
#all relationships for all variables, colored based on Fueltype
#diagonals are all histograms because they are univariate relationships
sns.pairplot(cars_data, kind = "scatter", hue = "FuelType", diag_kind = "hist")
plt.show()

# %%
tips_data = pd.read_csv("TIPS.csv", index_col = 0)
tips_data.dropna(axis = 0, inplace = True)
tips_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86 entries, 1 to 99
# Data columns (total 7 columns):
# TotalBill    86 non-null float64
# Tips         86 non-null float64
# Smoker       86 non-null object
# Day          86 non-null object
# Time         86 non-null object
# Size         86 non-null float64
# Gender       86 non-null object
# dtypes: float64(3), object(4)
# memory usage: 5.4+ KB

# %%
plt.hist(tips_data['Day'])
plt.title("Histogram of Day")
plt.xlabel("Day")
plt.ylabel("Count")
plt.show()

# %%
tips_data['Day'].value_counts()
# Out:
# Sat     33
# Sun     32
# Thur    12
# Fri      9
# Name: Day, dtype: int64

# %%
tips_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86 entries, 1 to 99
# Data columns (total 7 columns):
# TotalBill    86 non-null float64
# Tips         86 non-null float64
# Smoker       86 non-null object
# Day          86 non-null object
# Time         86 non-null object
# Size         86 non-null float64
# Gender       86 non-null object
# dtypes: float64(3), object(4)
# memory usage: 5.4+ KB

# %%
dayrank = dict(zip(list(tips_data['Day']), list(tips_data['Day'].rank())))
print(dayrank)
# Out:
# {'Sun': 58.5, 'Sat': 26.0, 'Thur': 80.5, 'Fri': 5.0}

# %%
sns.regplot(x = tips_data['Day'].rank(), y = tips_data['Tips'], data = tips_data, fit_reg = False)

# %%
sns.boxplot(x = tips_data['Tips'], y = tips_data['Day'])
plt.show()

# %%
tips_data.dtypes
# Out:
# TotalBill    float64
# Tips         float64
# Smoker        object
# Day           object
# Time          object
# Size         float64
# Gender        object
# dtype: object

# %%
import pandas as pd
s1 = pd.Series([7.3, 3.4], index=['a', 'c'])
s2 = pd.Series([-2.1, -1.5], index=['b', 'c'])
print(s1+s2)
# Out:
# a    NaN
# b    NaN
# c    1.9
# dtype: float64

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
'year': [2000, 2001, 2002, 2001, 2002, 2003],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

df = pd.DataFrame(data)
print(df)
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
print(df.columns)
# Out:
# Index(['state', 'year', 'pop'], dtype='object')

# %%
for column in df.columns:
    print(column)
# Out:
# state
# year
# pop

# %%
print(list(df.columns.values))
# Out:
# ['state', 'year', 'pop']

# %%
data2 = {'state': ['NY', 'NY', 'NY', 'Scranton', 'Scranton', 'Scranton'],
'year': [2000, 2001, 2002, 2001, 2002, 2003],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

df2  = pd.DataFrame(data2)
df3 = df.merge(df2, how = "outer")

print(df3)
# Out:
#        state  year  pop
# 0       Ohio  2000  1.5
# 1       Ohio  2001  1.7
# 2       Ohio  2002  3.6
# 3     Nevada  2001  2.4
# 4     Nevada  2002  2.9
# 5     Nevada  2003  3.2
# 6         NY  2000  1.5
# 7         NY  2001  1.7
# 8         NY  2002  3.6
# 9   Scranton  2001  2.4
# 10  Scranton  2002  2.9
# 11  Scranton  2003  3.2

# %%
count = 0
for column in tips_data.columns:
    print(column, sep = " ", end = " ")
    count+=1
print(count)
# Out:
# TotalBill Tips Smoker Day Time Size Gender 7

# %%
tips_data = pd.read_csv('TIPS.csv', index_col = 0)
tips_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 1 to 100
# Data columns (total 7 columns):
# TotalBill    98 non-null float64
# Tips         94 non-null float64
# Smoker       93 non-null object
# Day          93 non-null object
# Time         97 non-null object
# Size         99 non-null float64
# Gender       93 non-null object
# dtypes: float64(3), object(4)
# memory usage: 6.2+ KB

# %%
tips_data.dropna(axis = 0, inplace = True)
tips_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86 entries, 1 to 99
# Data columns (total 7 columns):
# TotalBill    86 non-null float64
# Tips         86 non-null float64
# Smoker       86 non-null object
# Day          86 non-null object
# Time         86 non-null object
# Size         86 non-null float64
# Gender       86 non-null object
# dtypes: float64(3), object(4)
# memory usage: 5.4+ KB

# %%
tips_data['Size'] = tips_data['Size'].astype("int64")
tips_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86 entries, 1 to 99
# Data columns (total 7 columns):
# TotalBill    86 non-null float64
# Tips         86 non-null float64
# Smoker       86 non-null object
# Day          86 non-null object
# Time         86 non-null object
# Size         86 non-null int64
# Gender       86 non-null object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 5.4+ KB

# %%
tips_data = pd.read_csv('TIPS.csv', index_col = 0)
tips_data.describe()
# Out:
#        TotalBill       Tips       Size
# count  98.000000  94.000000  99.000000
# mean   19.805408   3.036170   2.525253
# std     7.950817   1.201806   0.824911
# min     3.070000   1.000000   1.000000
# 25%    15.017500   2.035000   2.000000
# 50%    18.285000   3.000000   2.000000
# 75%    23.965000   3.577500   3.000000
# max    48.270000   6.730000   4.000000

# %%
print(tips_data.isnull().sum())
# Out:
# TotalBill    2
# Tips         6
# Smoker       7
# Day          7
# Time         3
# Size         1
# Gender       7
# dtype: int64

# %%
print("Range of Total Bill is: ",tips_data['TotalBill'].max()-tips_data['TotalBill'].min())
# Out:
# Range of Total Bill is:  45.2

# %%
numeric_data = tips_data.select_dtypes(exclude = ["object"])
cor_matrix = numeric_data.corr()
print(cor_matrix)
# Out:
#            TotalBill      Tips      Size
# TotalBill   1.000000  0.764716  0.587403
# Tips        0.764716  1.000000  0.448241
# Size        0.587403  0.448241  1.000000
